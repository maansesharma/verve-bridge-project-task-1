# %%
import  pandas as pd 
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\mansi\OneDrive\Documents\nba_draft_combine_all_years.csv")
data
# Out:
#      Unnamed: 0                 Player  Year  Draft pick  Height (No Shoes)  \
# 0             0          Blake Griffin  2009         1.0              80.50
# 1             1      Terrence Williams  2009        11.0              77.00
# 2             2       Gerald Henderson  2009        12.0              76.00
# 3             3       Tyler Hansbrough  2009        13.0              80.25
# 4             4             Earl Clark  2009        14.0              80.50
# ..          ...                    ...   ...         ...                ...
# 512         512              Peter Jok  2017         NaN              76.25
# 513         513           Rawle Alkins  2017         NaN              74.50
# 514         514  Sviatoslav Mykhailiuk  2017         NaN              78.50
# 515         515           Thomas Welsh  2017         NaN              83.50
# 516         516           V.J. Beachem  2017         NaN              78.25
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                517 non-null    int64
#  1   Player                    517 non-null    object
#  2   Year                      517 non-null    int64
#  3   Draft pick                384 non-null    float64
#  4   Height (No Shoes)         517 non-null    float64
#  5   Height (With Shoes)       516 non-null    float64
#  6   Wingspan                  517 non-null    float64
#  7   Standing reach            517 non-null    float64
#  8   Vertical (Max)            450 non-null    float64
#  9   Vertical (Max Reach)      450 non-null    float64
#  10  Vertical (No Step)        450 non-null    float64
#  11  Vertical (No Step Reach)  450 non-null    float64
#  12  Weight                    516 non-null    float64
# ...

# %%
data.head()
# Out:
#    Unnamed: 0             Player  Year  Draft pick  Height (No Shoes)  \
# 0           0      Blake Griffin  2009         1.0              80.50
# 1           1  Terrence Williams  2009        11.0              77.00
# 2           2   Gerald Henderson  2009        12.0              76.00
# 3           3   Tyler Hansbrough  2009        13.0              80.25
# 4           4         Earl Clark  2009        14.0              80.50
#
#    Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                82.00     83.25           105.0            35.5
# 1                78.25     81.00           103.5            37.0
# 2                77.00     82.25           102.5            35.0
# 3                81.50     83.50           106.0            34.0
# 4                82.25     86.50           109.5            33.0
#
#    Vertical (Max Reach)  Vertical (No Step)  Vertical (No Step Reach)  Weight  \
# ...

# %%
data.tail()
# Out:
#      Unnamed: 0                 Player  Year  Draft pick  Height (No Shoes)  \
# 512         512              Peter Jok  2017         NaN              76.25
# 513         513           Rawle Alkins  2017         NaN              74.50
# 514         514  Sviatoslav Mykhailiuk  2017         NaN              78.50
# 515         515           Thomas Welsh  2017         NaN              83.50
# 516         516           V.J. Beachem  2017         NaN              78.25
#
#      Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 512                77.75     80.00           102.0            31.0
# 513                75.75     80.75            99.0            40.5
# 514                79.50     77.00           100.0            33.0
# 515                84.50     84.00           109.5             NaN
# 516                80.00     82.25           104.5            37.0
#
#      Vertical (Max Reach)  Vertical (No Step)  Vertical (No Step Reach)  \
# ...

# %%
data.shape
# Out:
# (517, 19)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                    0
# Player                        0
# Year                          0
# Draft pick                  133
# Height (No Shoes)             0
# Height (With Shoes)           1
# Wingspan                      0
# Standing reach                0
# Vertical (Max)               67
# Vertical (Max Reach)         67
# Vertical (No Step)           67
# Vertical (No Step Reach)     67
# Weight                        1
# Body Fat                      3
# Hand (Length)                47
# Hand (Width)                 49
# Bench                       233
# Agility                      73
# Sprint                       71
# dtype: int64

# %%
data_dub = data.duplicated().any()
data_dub
# Out:
# False

# %%
data = data.drop_duplicates()
data
# Out:
#      Unnamed: 0                 Player  Year  Draft pick  Height (No Shoes)  \
# 0             0          Blake Griffin  2009         1.0              80.50
# 1             1      Terrence Williams  2009        11.0              77.00
# 2             2       Gerald Henderson  2009        12.0              76.00
# 3             3       Tyler Hansbrough  2009        13.0              80.25
# 4             4             Earl Clark  2009        14.0              80.50
# ..          ...                    ...   ...         ...                ...
# 512         512              Peter Jok  2017         NaN              76.25
# 513         513           Rawle Alkins  2017         NaN              74.50
# 514         514  Sviatoslav Mykhailiuk  2017         NaN              78.50
# 515         515           Thomas Welsh  2017         NaN              83.50
# 516         516           V.J. Beachem  2017         NaN              78.25
#
# ...

# %%
data.shape
# Out:
# (517, 19)

# %%
data.describe()
# Out:
#        Unnamed: 0         Year  Draft pick  Height (No Shoes)  \
# count  517.000000   517.000000  384.000000         517.000000
# mean   258.000000  2013.187621   28.492188          77.609284
# std    149.389312     2.531507   15.888973           3.287633
# min      0.000000  2009.000000    1.000000          68.250000
# 25%    129.000000  2011.000000   15.000000          75.250000
# 50%    258.000000  2013.000000   28.000000          77.750000
# 75%    387.000000  2015.000000   41.000000          80.000000
# max    516.000000  2017.000000   60.000000          85.250000
#
#        Height (With Shoes)    Wingspan  Standing reach  Vertical (Max)  \
# count           516.000000  517.000000      517.000000      450.000000
# mean             78.898740   82.497292      103.275629       35.136667
# std               3.275837    3.943068        4.897515        3.561688
# min              69.500000   70.000000       88.500000       25.000000
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Year', 'Draft pick', 'Height (No Shoes)',
#        'Height (With Shoes)', 'Wingspan', 'Standing reach', 'Vertical (Max)',
#        'Vertical (Max Reach)', 'Vertical (No Step)',
#        'Vertical (No Step Reach)', 'Weight', 'Body Fat', 'Hand (Length)',
#        'Hand (Width)', 'Bench', 'Agility', 'Sprint'],
#       dtype='object')

# %%
sns.histplot( x = data['Agility'] , data = data)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[306], line 2
#       1 sns.histplot( x = data['Agility'] , data = data)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
data['Agility'].value_counts()
# Out:
# Agility
# 11.15    10
# 11.10     8
# 11.68     7
# 11.00     7
# 11.45     6
#          ..
# 10.48     1
# 11.84     1
# 12.35     1
# 10.65     1
# 12.40     1
# Name: count, Length: 191, dtype: int64

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                    0
# Player                        0
# Year                          0
# Draft pick                  133
# Height (No Shoes)             0
# Height (With Shoes)           1
# Wingspan                      0
# Standing reach                0
# Vertical (Max)               67
# Vertical (Max Reach)         67
# Vertical (No Step)           67
# Vertical (No Step Reach)     67
# Weight                        1
# Body Fat                      3
# Hand (Length)                47
# Hand (Width)                 49
# Bench                       233
# Agility                      73
# Sprint                       71
# dtype: int64

# %%
nba_data = data.drop(columns= ['Draft pick', 'Bench' , 'Hand (Width)'])

# %%
nba_data
# Out:
#      Unnamed: 0                 Player  Year  Height (No Shoes)  \
# 0             0          Blake Griffin  2009              80.50
# 1             1      Terrence Williams  2009              77.00
# 2             2       Gerald Henderson  2009              76.00
# 3             3       Tyler Hansbrough  2009              80.25
# 4             4             Earl Clark  2009              80.50
# ..          ...                    ...   ...                ...
# 512         512              Peter Jok  2017              76.25
# 513         513           Rawle Alkins  2017              74.50
# 514         514  Sviatoslav Mykhailiuk  2017              78.50
# 515         515           Thomas Welsh  2017              83.50
# 516         516           V.J. Beachem  2017              78.25
#
#      Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                  82.00     83.25           105.0            35.5
# ...

# %%
data.shape
# Out:
# (517, 19)

# %%
data.isnull()
# Out:
#      Unnamed: 0  Player   Year  Draft pick  Height (No Shoes)  \
# 0         False   False  False       False              False
# 1         False   False  False       False              False
# 2         False   False  False       False              False
# 3         False   False  False       False              False
# 4         False   False  False       False              False
# ..          ...     ...    ...         ...                ...
# 512       False   False  False        True              False
# 513       False   False  False        True              False
# 514       False   False  False        True              False
# 515       False   False  False        True              False
# 516       False   False  False        True              False
#
#      Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                  False     False           False           False
# 1                  False     False           False           False
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                    0
# Player                        0
# Year                          0
# Draft pick                  133
# Height (No Shoes)             0
# Height (With Shoes)           1
# Wingspan                      0
# Standing reach                0
# Vertical (Max)               67
# Vertical (Max Reach)         67
# Vertical (No Step)           67
# Vertical (No Step Reach)     67
# Weight                        1
# Body Fat                      3
# Hand (Length)                47
# Hand (Width)                 49
# Bench                       233
# Agility                      73
# Sprint                       71
# dtype: int64

# %%
data2 = data.fillna(value = 0)

# %%
data2
# Out:
#      Unnamed: 0                 Player  Year  Draft pick  Height (No Shoes)  \
# 0             0          Blake Griffin  2009         1.0              80.50
# 1             1      Terrence Williams  2009        11.0              77.00
# 2             2       Gerald Henderson  2009        12.0              76.00
# 3             3       Tyler Hansbrough  2009        13.0              80.25
# 4             4             Earl Clark  2009        14.0              80.50
# ..          ...                    ...   ...         ...                ...
# 512         512              Peter Jok  2017         0.0              76.25
# 513         513           Rawle Alkins  2017         0.0              74.50
# 514         514  Sviatoslav Mykhailiuk  2017         0.0              78.50
# 515         515           Thomas Welsh  2017         0.0              83.50
# 516         516           V.J. Beachem  2017         0.0              78.25
#
# ...

# %%
data.isnull().sum().sum()
# Out:
# 879

# %%
data2.isnull().sum().sum()
# Out:
# 0

# %%
data5 = data.fillna(value= data['Vertical (Max)'].mean())
data5
# Out:
#      Unnamed: 0                 Player  Year  Draft pick  Height (No Shoes)  \
# 0             0          Blake Griffin  2009    1.000000              80.50
# 1             1      Terrence Williams  2009   11.000000              77.00
# 2             2       Gerald Henderson  2009   12.000000              76.00
# 3             3       Tyler Hansbrough  2009   13.000000              80.25
# 4             4             Earl Clark  2009   14.000000              80.50
# ..          ...                    ...   ...         ...                ...
# 512         512              Peter Jok  2017   35.136667              76.25
# 513         513           Rawle Alkins  2017   35.136667              74.50
# 514         514  Sviatoslav Mykhailiuk  2017   35.136667              78.50
# 515         515           Thomas Welsh  2017   35.136667              83.50
# 516         516           V.J. Beachem  2017   35.136667              78.25
#
# ...

# %%
data5 = data.fillna(value= data['Vertical (Max Reach)'].mean())
data5
# Out:
#      Unnamed: 0                 Player  Year  Draft pick  Height (No Shoes)  \
# 0             0          Blake Griffin  2009    1.000000              80.50
# 1             1      Terrence Williams  2009   11.000000              77.00
# 2             2       Gerald Henderson  2009   12.000000              76.00
# 3             3       Tyler Hansbrough  2009   13.000000              80.25
# 4             4             Earl Clark  2009   14.000000              80.50
# ..          ...                    ...   ...         ...                ...
# 512         512              Peter Jok  2017  138.166667              76.25
# 513         513           Rawle Alkins  2017  138.166667              74.50
# 514         514  Sviatoslav Mykhailiuk  2017  138.166667              78.50
# 515         515           Thomas Welsh  2017  138.166667              83.50
# 516         516           V.J. Beachem  2017  138.166667              78.25
#
# ...

# %%
data5 = data.fillna(value= data['Vertical (No Step Reach)'].mean())
data5
# Out:
#      Unnamed: 0                 Player  Year  Draft pick  Height (No Shoes)  \
# 0             0          Blake Griffin  2009    1.000000              80.50
# 1             1      Terrence Williams  2009   11.000000              77.00
# 2             2       Gerald Henderson  2009   12.000000              76.00
# 3             3       Tyler Hansbrough  2009   13.000000              80.25
# 4             4             Earl Clark  2009   14.000000              80.50
# ..          ...                    ...   ...         ...                ...
# 512         512              Peter Jok  2017  132.621111              76.25
# 513         513           Rawle Alkins  2017  132.621111              74.50
# 514         514  Sviatoslav Mykhailiuk  2017  132.621111              78.50
# 515         515           Thomas Welsh  2017  132.621111              83.50
# 516         516           V.J. Beachem  2017  132.621111              78.25
#
# ...

# %%
data5 = data.fillna(value= data['Vertical (No Step Reach)'].mean())
data5
# Out:
#      Unnamed: 0                 Player  Year  Draft pick  Height (No Shoes)  \
# 0             0          Blake Griffin  2009    1.000000              80.50
# 1             1      Terrence Williams  2009   11.000000              77.00
# 2             2       Gerald Henderson  2009   12.000000              76.00
# 3             3       Tyler Hansbrough  2009   13.000000              80.25
# 4             4             Earl Clark  2009   14.000000              80.50
# ..          ...                    ...   ...         ...                ...
# 512         512              Peter Jok  2017  132.621111              76.25
# 513         513           Rawle Alkins  2017  132.621111              74.50
# 514         514  Sviatoslav Mykhailiuk  2017  132.621111              78.50
# 515         515           Thomas Welsh  2017  132.621111              83.50
# 516         516           V.J. Beachem  2017  132.621111              78.25
#
# ...

# %%
data.isnull()
# Out:
#      Unnamed: 0  Player   Year  Draft pick  Height (No Shoes)  \
# 0         False   False  False       False              False
# 1         False   False  False       False              False
# 2         False   False  False       False              False
# 3         False   False  False       False              False
# 4         False   False  False       False              False
# ..          ...     ...    ...         ...                ...
# 512       False   False  False        True              False
# 513       False   False  False        True              False
# 514       False   False  False        True              False
# 515       False   False  False        True              False
# 516       False   False  False        True              False
#
#      Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                  False     False           False           False
# 1                  False     False           False           False
# ...

# %%
data5 = data.drop(columns = ['Bench' , 'Draft pick'])
data5
# Out:
#      Unnamed: 0                 Player  Year  Height (No Shoes)  \
# 0             0          Blake Griffin  2009              80.50
# 1             1      Terrence Williams  2009              77.00
# 2             2       Gerald Henderson  2009              76.00
# 3             3       Tyler Hansbrough  2009              80.25
# 4             4             Earl Clark  2009              80.50
# ..          ...                    ...   ...                ...
# 512         512              Peter Jok  2017              76.25
# 513         513           Rawle Alkins  2017              74.50
# 514         514  Sviatoslav Mykhailiuk  2017              78.50
# 515         515           Thomas Welsh  2017              83.50
# 516         516           V.J. Beachem  2017              78.25
#
#      Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                  82.00     83.25           105.0            35.5
# ...

# %%
data5.isnull().sum()
data5
# Out:
#      Unnamed: 0                 Player  Year  Height (No Shoes)  \
# 0             0          Blake Griffin  2009              80.50
# 1             1      Terrence Williams  2009              77.00
# 2             2       Gerald Henderson  2009              76.00
# 3             3       Tyler Hansbrough  2009              80.25
# 4             4             Earl Clark  2009              80.50
# ..          ...                    ...   ...                ...
# 512         512              Peter Jok  2017              76.25
# 513         513           Rawle Alkins  2017              74.50
# 514         514  Sviatoslav Mykhailiuk  2017              78.50
# 515         515           Thomas Welsh  2017              83.50
# 516         516           V.J. Beachem  2017              78.25
#
#      Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                  82.00     83.25           105.0            35.5
# ...

# %%
data5.isnull().sum()
# Out:
# Unnamed: 0                   0
# Player                       0
# Year                         0
# Height (No Shoes)            0
# Height (With Shoes)          1
# Wingspan                     0
# Standing reach               0
# Vertical (Max)              67
# Vertical (Max Reach)        67
# Vertical (No Step)          67
# Vertical (No Step Reach)    67
# Weight                       1
# Body Fat                     3
# Hand (Length)               47
# Hand (Width)                49
# Agility                     73
# Sprint                      71
# dtype: int64

# %%
data5
# Out:
#      Unnamed: 0                 Player  Year  Height (No Shoes)  \
# 0             0          Blake Griffin  2009              80.50
# 1             1      Terrence Williams  2009              77.00
# 2             2       Gerald Henderson  2009              76.00
# 3             3       Tyler Hansbrough  2009              80.25
# 4             4             Earl Clark  2009              80.50
# ..          ...                    ...   ...                ...
# 512         512              Peter Jok  2017              76.25
# 513         513           Rawle Alkins  2017              74.50
# 514         514  Sviatoslav Mykhailiuk  2017              78.50
# 515         515           Thomas Welsh  2017              83.50
# 516         516           V.J. Beachem  2017              78.25
#
#      Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                  82.00     83.25           105.0            35.5
# ...

# %%
data5.isnull()
# Out:
#      Unnamed: 0  Player   Year  Height (No Shoes)  Height (With Shoes)  \
# 0         False   False  False              False                False
# 1         False   False  False              False                False
# 2         False   False  False              False                False
# 3         False   False  False              False                False
# 4         False   False  False              False                False
# ..          ...     ...    ...                ...                  ...
# 512       False   False  False              False                False
# 513       False   False  False              False                False
# 514       False   False  False              False                False
# 515       False   False  False              False                False
# 516       False   False  False              False                False
#
#      Wingspan  Standing reach  Vertical (Max)  Vertical (Max Reach)  \
# ...

# %%
data5.shape
# Out:
# (517, 17)

# %%
data.isnull()
# Out:
#      Unnamed: 0  Player   Year  Draft pick  Height (No Shoes)  \
# 0         False   False  False       False              False
# 1         False   False  False       False              False
# 2         False   False  False       False              False
# 3         False   False  False       False              False
# 4         False   False  False       False              False
# ..          ...     ...    ...         ...                ...
# 512       False   False  False        True              False
# 513       False   False  False        True              False
# 514       False   False  False        True              False
# 515       False   False  False        True              False
# 516       False   False  False        True              False
#
#      Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                  False     False           False           False
# 1                  False     False           False           False
# ...

# %%
data5.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Year', 'Height (No Shoes)',
#        'Height (With Shoes)', 'Wingspan', 'Standing reach', 'Vertical (Max)',
#        'Vertical (Max Reach)', 'Vertical (No Step)',
#        'Vertical (No Step Reach)', 'Weight', 'Body Fat', 'Hand (Length)',
#        'Hand (Width)', 'Agility', 'Sprint'],
#       dtype='object')

# %%
data5.isnull()
# Out:
#      Unnamed: 0  Player   Year  Height (No Shoes)  Height (With Shoes)  \
# 0         False   False  False              False                False
# 1         False   False  False              False                False
# 2         False   False  False              False                False
# 3         False   False  False              False                False
# 4         False   False  False              False                False
# ..          ...     ...    ...                ...                  ...
# 512       False   False  False              False                False
# 513       False   False  False              False                False
# 514       False   False  False              False                False
# 515       False   False  False              False                False
# 516       False   False  False              False                False
#
#      Wingspan  Standing reach  Vertical (Max)  Vertical (Max Reach)  \
# ...

# %%
data5.isnull().sum()
# Out:
# Unnamed: 0                   0
# Player                       0
# Year                         0
# Height (No Shoes)            0
# Height (With Shoes)          1
# Wingspan                     0
# Standing reach               0
# Vertical (Max)              67
# Vertical (Max Reach)        67
# Vertical (No Step)          67
# Vertical (No Step Reach)    67
# Weight                       1
# Body Fat                     3
# Hand (Length)               47
# Hand (Width)                49
# Agility                     73
# Sprint                      71
# dtype: int64

# %%
data_dup = data5.fillna( value = data5['Hand (Length)'].mean())

# %%
data_dup
# Out:
#      Unnamed: 0                 Player  Year  Height (No Shoes)  \
# 0             0          Blake Griffin  2009              80.50
# 1             1      Terrence Williams  2009              77.00
# 2             2       Gerald Henderson  2009              76.00
# 3             3       Tyler Hansbrough  2009              80.25
# 4             4             Earl Clark  2009              80.50
# ..          ...                    ...   ...                ...
# 512         512              Peter Jok  2017              76.25
# 513         513           Rawle Alkins  2017              74.50
# 514         514  Sviatoslav Mykhailiuk  2017              78.50
# 515         515           Thomas Welsh  2017              83.50
# 516         516           V.J. Beachem  2017              78.25
#
#      Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                  82.00     83.25           105.0       35.500000
# ...

# %%
data_dup = data5.fillna( value = data5['Hand (Width)'].mean())

# %%
data_dup
# Out:
#      Unnamed: 0                 Player  Year  Height (No Shoes)  \
# 0             0          Blake Griffin  2009              80.50
# 1             1      Terrence Williams  2009              77.00
# 2             2       Gerald Henderson  2009              76.00
# 3             3       Tyler Hansbrough  2009              80.25
# 4             4             Earl Clark  2009              80.50
# ..          ...                    ...   ...                ...
# 512         512              Peter Jok  2017              76.25
# 513         513           Rawle Alkins  2017              74.50
# 514         514  Sviatoslav Mykhailiuk  2017              78.50
# 515         515           Thomas Welsh  2017              83.50
# 516         516           V.J. Beachem  2017              78.25
#
#      Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                  82.00     83.25           105.0       35.500000
# ...

# %%
data5.head(100)
# Out:
#     Unnamed: 0             Player  Year  Height (No Shoes)  \
# 0            0      Blake Griffin  2009              80.50
# 1            1  Terrence Williams  2009              77.00
# 2            2   Gerald Henderson  2009              76.00
# 3            3   Tyler Hansbrough  2009              80.25
# 4            4         Earl Clark  2009              80.50
# ..         ...                ...   ...                ...
# 95          95   Mikhail Torrance  2010              76.00
# 96          96    Sherron Collins  2010              70.25
# 97          97  Sylven Landesberg  2010              76.75
# 98          98    Jimmer Fredette  2011              72.75
# 99          99      Klay Thompson  2011              77.75
#
#     Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                 82.00     83.25          105.00            35.5
# 1                 78.25     81.00          103.50            37.0
# ...

# %%
new_data = data5.dropna()

# %%
new_data
# Out:
#      Unnamed: 0                 Player  Year  Height (No Shoes)  \
# 15           15           Damion James  2009              78.25
# 19           19        Greivis Vasquez  2009              76.75
# 35           35             Gani Lawal  2009              79.75
# 38           38         Luke Harangody  2009              78.25
# 50           50              John Wall  2010              74.75
# ..          ...                    ...   ...                ...
# 511         511            P.J. Dozier  2017              77.25
# 512         512              Peter Jok  2017              76.25
# 513         513           Rawle Alkins  2017              74.50
# 514         514  Sviatoslav Mykhailiuk  2017              78.50
# 516         516           V.J. Beachem  2017              78.25
#
#      Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 15                 79.50     84.75           106.0            37.0
# ...

# %%
new_data['Player'].value_counts().sum()
# Out:
# 393

# %%
new_data['Height (No Shoes)'].value_counts()
# Out:
# Height (No Shoes)
# 80.75    17
# 76.75    16
# 76.50    15
# 77.25    14
# 79.50    14
#          ..
# 83.00     1
# 70.00     1
# 68.25     1
# 70.75     1
# 84.75     1
# Name: count, Length: 63, dtype: int64

# %%
sns.histplot(x = data['Height (No Shoes)'], data =data)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Height (No Shoes)', ylabel='Count'>

# %%
sns.histplot(x = data['Height (With Shoes)'], data =data)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Height (With Shoes)', ylabel='Count'>

# %%
sns.histplot(x = data['Wingspan'], data =data)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Wingspan', ylabel='Count'>

# %%
sns.histplot(x = data['Weight'], data =data)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Weight', ylabel='Count'>

# %%
new_data['Vertical (Max Reach)'].value_counts()
# Out:
# Vertical (Max Reach)
# 138.00    31
# 142.00    22
# 139.50    21
# 141.50    20
# 134.00    18
# 140.00    17
# 141.00    17
# 138.50    16
# 137.50    16
# 140.50    15
# 144.00    15
# 136.00    13
# 136.50    13
# 139.00    12
# 137.00    11
# 135.00    11
# 143.00    10
# 142.50    10
# 133.50    10
# 133.00     9
# 134.50     9
# 143.50     8
# 135.50     8
# 145.50     6
# 132.50     5
# 145.00     5
# 132.00     5
# 144.50     5
# 130.50     4
# 146.00     3
# 127.00     3
# 131.50     3
# 129.50     3
# 129.00     3
# 131.00     2
# 128.50     2
# 126.50     2
# 127.50     2
# 128.00     2
# 137.75     1
# 125.50     1
# 147.00     1
# 146.50     1
# 130.00     1
# 147.50     1
# Name: count, dtype: int64

# %%
sns.histplot(x = new_data['Vertical (Max Reach)'], data =data)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Vertical (Max Reach)', ylabel='Count'>

# %%
sns.histplot(x = data['Vertical (Max)'], data =data)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Vertical (Max)', ylabel='Count'>

# %%
print("vertical MAX Reach is :" , new_data['Vertical (Max Reach)'].max())
print("vertical no step reach is : ", new_data['Vertical (No Step Reach)'].max())
print("body fat MAX is : " , new_data['Body Fat'].max())
print("max height with no shoes is", new_data['Height (No Shoes)'].max())
print("max height with shoes is :" , new_data['Height (With Shoes)'].max())
# Out:
# vertical MAX Reach is : 147.5
# vertical no step reach is :  144.0
# body fat MAX is :  16.4
# max height with no shoes is 85.25
# max height with shoes is : 86.25

# %%
new_data['Year'].value_counts()
# Out:
# Year
# 2012    54
# 2013    51
# 2014    51
# 2011    50
# 2017    50
# 2016    48
# 2015    45
# 2010    40
# 2009     4
# Name: count, dtype: int64

# %%
sns.histplot(new_data['Year'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Year', ylabel='Count'>

# %%
sns.histplot(x = new_data['Year'], data = data)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Year', ylabel='Count'>

# %%
new_data['Agility' ].max()
# Out:
# 13.44

# %%
new_data['Agility' ].min()
# Out:
# 10.07

# %%
sns.histplot(x = new_data['Agility'], data = data)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Agility', ylabel='Count'>

# %%
        sns.heatmap(data=new_data  , x=new_data['Player'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[481], line 1
# ----> 1 sns.heatmap(data=new_data  , x=new_data['Player'])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
# ...
